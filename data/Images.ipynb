# %%
from PIL import Image
im = Image.open("Leia2.png")
im.size
# Out:
# (512, 512)

# %%
from matplotlib.pyplot import imshow
imshow(im.rotate(45))

# %%
imshow(im.resize((1000,1000)))

# %%
im.convert("L")
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7DAC1A4A20>

# %%
np.array(im.convert("L"))
# Out:
# array([[117, 115, 113, ..., 101, 104, 106],
#        [119, 116, 113, ..., 100, 102, 104],
#        [120, 118, 113, ...,  97,  99, 101],
#        ...,
#        [146, 148, 149, ..., 217, 225, 230],
#        [141, 143, 145, ..., 217, 224, 228],
#        [137, 139, 142, ..., 216, 222, 226]], dtype=uint8)
